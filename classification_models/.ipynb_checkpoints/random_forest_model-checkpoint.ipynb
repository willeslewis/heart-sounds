# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

# %%
train=pd.read_csv('/Users/William/Desktop/heart-sounds/preprocessed_data/training.csv')

# %%
train.head()
# Out:
#      type  avg_rmse  std_rmse   kur_rmse  skew_rmse   avg_zcr   std_zcr  \
# 0  normal       1.0  2.898545  17.086128   4.186741  0.288209  0.131582
# 1  normal       1.0  2.813071  16.969061   4.162484  0.282660  0.132833
# 2  normal       1.0  1.776919  18.132544   4.333302  0.431573  0.132903
# 3  normal       1.0  0.421270  20.812918   4.658125  0.470988  0.087098
# 4  normal       1.0  0.786380  22.398094   4.764040  0.458718  0.104123
#
#      kur_zcr  skew_zcr  avg_mfcc_0      ...       kur_mfcc_17.1  skew_mfcc_27  \
# 0  -0.265798 -0.927572  -34.228432      ...            0.703380      0.393901
# 1  -0.472778 -0.831983  -26.929511      ...            0.935444      0.429875
# 2   3.063192 -2.040150  108.769065      ...           -0.228381      0.172020
# 3  13.695402 -3.665996  160.678292      ...           -0.879921     -0.045600
# 4   7.719082 -2.776748  150.833890      ...           -0.872355     -0.347222
#
#    avg_mfcc_28  std_mfcc_28  kur_mfcc_18.1  skew_mfcc_28  avg_mfcc_29  \
# 0    -2.007890     3.478149       0.136677     -0.251857    -2.287456
# 1    -2.225842     3.420045       0.092548     -0.228392    -2.352415
# 2    -0.935877     3.627494      -0.337411      0.154491    -1.337516
# 3     0.122779     3.601674      -0.771596      0.351720     0.250797
# 4    -1.488772     3.261399       0.620828     -0.518160    -0.929031
#
#    std_mfcc_29  kur_mfcc_19.1  skew_mfcc_29
# 0     3.291511       0.123659     -0.453357
# 1     3.278060       0.272468     -0.449606
# 2     3.165086      -0.410650     -0.322942
# 3     4.057731      -0.812184     -0.241561
# 4     3.254972      -0.552612     -0.215942
#
# [5 rows x 129 columns]

# %%
train = train.sample(frac=1)
Xtrain = train.drop('type',axis=1)
ytrain = train['type']
lbl = LabelEncoder()
lbl.fit(ytrain)
ytrain = lbl.transform(ytrain)

# %%
rf = RandomForestClassifier()

gsrf = GridSearchCV(rf, param_grid = {'n_estimators':[10,50,150,250]}, n_jobs = -1,return_train_score=True,cv=10)

gsrf.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [10, 50, 150, 250]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
gsrf.get_params().keys()
# Out:
# dict_keys(['return_train_score', 'fit_params', 'error_score', 'estimator__oob_score', 'estimator__min_samples_split', 'estimator__warm_start', 'estimator__min_impurity_split', 'estimator__n_jobs', 'estimator__min_weight_fraction_leaf', 'refit', 'estimator__max_depth', 'param_grid', 'estimator__verbose', 'pre_dispatch', 'estimator__criterion', 'estimator__max_features', 'n_jobs', 'iid', 'verbose', 'estimator__max_leaf_nodes', 'cv', 'estimator__min_samples_leaf', 'estimator__bootstrap', 'estimator__class_weight', 'estimator__n_estimators', 'estimator', 'estimator__random_state', 'scoring'])

# %%
gsrf.cv_results_
# Out:
# {'mean_fit_time': array([ 0.2825063 ,  1.31139627,  3.91720123,  6.08875978]),
#  'mean_score_time': array([ 0.00487878,  0.01168861,  0.03107586,  0.04058306]),
#  'mean_test_score': array([ 0.95610425,  0.96364883,  0.96536351,  0.96502058]),
#  'mean_train_score': array([ 0.99859043,  0.99996188,  1.        ,  1.        ]),
#  'param_n_estimators': masked_array(data = [10 50 150 250],
#               mask = [False False False False],
#         fill_value = ?),
#  'params': ({'n_estimators': 10},
#   {'n_estimators': 50},
#   {'n_estimators': 150},
#   {'n_estimators': 250}),
#  'rank_test_score': array([4, 3, 1, 2], dtype=int32),
#  'split0_test_score': array([ 0.96245734,  0.96928328,  0.97269625,  0.96928328]),
#  'split0_train_score': array([ 0.99847503,  0.99961876,  1.        ,  1.        ]),
#  'split1_test_score': array([ 0.94178082,  0.96575342,  0.95547945,  0.95547945]),
#  'split1_train_score': array([ 0.9996189,  1.       ,  1.       ,  1.       ]),
#  'split2_test_score': array([ 0.96917808,  0.97260274,  0.96917808,  0.96575342]),
#  'split2_train_score': array([ 0.99885671,  1.        ,  1.        ,  1.        ]),
#  'split3_test_score': array([ 0.94863014,  0.96575342,  0.96575342,  0.96575342]),
#  'split3_train_score': array([ 0.99847561,  1.        ,  1.        ,  1.        ]),
#  'split4_test_score': array([ 0.94520548,  0.94863014,  0.96575342,  0.96232877]),
#  'split4_train_score': array([ 0.9992378,  1.       ,  1.       ,  1.       ]),
#  'split5_test_score': array([ 0.96232877,  0.96917808,  0.97945205,  0.9760274 ]),
#  'split5_train_score': array([ 0.99885671,  1.        ,  1.        ,  1.        ]),
#  'split6_test_score': array([ 0.95547945,  0.95547945,  0.95547945,  0.95890411]),
#  'split6_train_score': array([ 1.,  1.,  1.,  1.]),
#  'split7_test_score': array([ 0.96219931,  0.97594502,  0.97594502,  0.9862543 ]),
#  'split7_train_score': array([ 0.99771429,  1.        ,  1.        ,  1.        ]),
#  'split8_test_score': array([ 0.94501718,  0.95189003,  0.95189003,  0.94845361]),
#  'split8_train_score': array([ 0.99809524,  1.        ,  1.        ,  1.        ]),
#  'split9_test_score': array([ 0.96885813,  0.96193772,  0.96193772,  0.96193772]),
#  'split9_train_score': array([ 0.99657404,  1.        ,  1.        ,  1.        ]),
#  'std_fit_time': array([ 0.01449266,  0.0397205 ,  0.05033457,  0.77806151]),
#  'std_score_time': array([ 0.00230622,  0.0020724 ,  0.0033373 ,  0.01126789]),
#  'std_test_score': array([ 0.009758  ,  0.00857986,  0.0087627 ,  0.01004882]),
#  'std_train_score': array([ 0.00093331,  0.00011437,  0.        ,  0.        ])}

# %%
train.groupby('type').describe()
# Out:
#                  avg_mfcc_0   avg_mfcc_1  avg_mfcc_10  avg_mfcc_11  \
# type
# artifact count   711.000000   711.000000   711.000000   711.000000
#          mean    147.776104    55.757579    -1.863986    -3.448238
#          std      54.174880    48.190307     2.907511     4.062077
#          min    -113.426767    -2.829433   -12.367304   -17.700794
#          25%     143.040930    21.794390    -2.936069    -5.617833
#          50%     166.427775    42.000802    -1.189701    -2.111922
#          75%     179.567704    78.035243    -0.141140    -0.620087
#          max     191.762080   206.343573     5.372090     4.903761
# extrahls count   459.000000   459.000000   459.000000   459.000000
#          mean    100.231276    32.259309     2.453614     0.319012
#          std      79.367361    44.442801     2.010557     2.145256
#          min    -137.416658    -3.881223    -4.897713    -7.796996
#          25%      94.559471     3.049301     1.335520    -0.238476
#          50%     140.281871    10.365908     2.067527     0.995532
#          75%     155.860588    35.505215     2.973211     1.607235
#          max     165.050594   164.055699     9.560689     4.395414
# murmur   count  1179.000000  1179.000000  1179.000000  1179.000000
#          mean     65.287254    21.024786     7.295832     6.729028
#          std     125.669820    32.964296     3.554023     3.557603
#          min    -250.345792    -4.664382    -0.333581    -5.890364
#          25%      74.416840     1.094140     4.404765     4.031750
#          50%     131.069046     5.019573     6.511195     6.124891
#          75%     151.590743    16.014442     9.917925     8.916389
#          max     166.406461   159.711275    16.673300    18.805087
# normal   count   567.000000   567.000000   567.000000   567.000000
#          mean    115.208256    27.686049     1.393878    -0.355264
#          std      72.070083    36.955940     2.976062     3.079369
#          min    -156.717346    -3.367579    -5.787195   -11.954477
#          25%     117.786880     0.859015    -0.199373    -1.588716
#          50%     149.398236     7.936759     0.774197    -0.165765
#          75%     158.584285    52.196967     2.524181     0.818538
#          max     172.640210   144.919864    10.782581     9.732480
#
#                 avg_mfcc_12  avg_mfcc_13  avg_mfcc_14  avg_mfcc_15  \
# type
# artifact count   711.000000   711.000000   711.000000   711.000000
#          mean     -2.157296    -2.647888    -2.301112    -2.600867
#          std       2.338420     2.986744     2.423622     2.930778
#          min      -9.236721   -13.138779   -13.251314   -13.508647
#          25%      -3.502375    -4.072818    -3.723665    -4.140179
#          50%      -1.632442    -2.064530    -1.781331    -1.834432
#          75%      -0.450666    -0.434697    -0.409320    -0.423736
#          max       3.558987     4.694847     2.200668     2.872628
# extrahls count   459.000000   459.000000   459.000000   459.000000
#          mean      0.548571    -0.973579    -0.873483    -1.735161
#          std       1.433765     2.041363     1.356973     1.629384
#          min      -6.325702    -8.677488    -6.704508    -7.539197
#          25%      -0.231411    -1.579599    -1.675497    -2.766352
#          50%       0.581330    -0.382616    -0.696777    -1.454401
#          75%       1.462330     0.359370     0.072941    -0.552233
#          max       4.498078     3.169327     2.868579     2.349150
# murmur   count  1179.000000  1179.000000  1179.000000  1179.000000
#          mean      5.962418     5.067777     4.044429     3.510683
#          std       2.893609     2.584419     2.174574     2.349368
#          min      -1.842894    -3.361704    -3.940349    -6.670421
#          25%       3.795059     3.263023     2.586641     2.093858
#          50%       5.440771     4.760227     3.948238     3.505688
#          75%       7.630942     6.715323     5.490527     4.969809
#          max      14.580418    13.240515     9.587960    10.050583
# normal   count   567.000000   567.000000   567.000000   567.000000
#          mean      0.135785    -1.078761    -0.796146    -1.268776
#          std       2.004917     2.469358     1.891001     1.998403
#          min      -4.718995    -8.947762    -6.298342    -8.369119
#          25%      -0.872228    -2.357129    -1.929415    -2.319568
#          50%       0.000460    -0.793043    -0.828514    -1.070082
#          75%       0.821207    -0.052421    -0.063653    -0.360116
#          max       8.431477     6.913799     5.328826     5.265819
#
#                 avg_mfcc_16  avg_mfcc_17     ...       std_mfcc_29  \
# type                                         ...
# artifact count   711.000000   711.000000     ...        711.000000
#          mean     -1.542446    -1.565135     ...          3.530885
#          std       1.933774     2.027472     ...          0.464152
#          min      -8.628275    -9.224807     ...          2.259499
#          25%      -2.363367    -2.642243     ...          3.179970
#          50%      -1.189467    -1.179777     ...          3.514727
#          75%      -0.362425    -0.235802     ...          3.791184
#          max       4.982690     2.582669     ...          5.123982
# extrahls count   459.000000   459.000000     ...        459.000000
#          mean     -1.592166    -2.273457     ...          3.496132
#          std       1.425811     1.651527     ...          0.409694
#          min      -6.847981    -8.045239     ...          2.477822
#          25%      -2.463635    -3.254003     ...          3.231981
#          50%      -1.393661    -1.957518     ...          3.484128
#          75%      -0.598844    -1.103624     ...          3.741782
#          max       2.506443     0.839180     ...          4.908039
# murmur   count  1179.000000  1179.000000     ...       1179.000000
#          mean      3.191213     2.699981     ...          3.444453
#          std       2.363494     2.312460     ...          0.501777
#          min      -4.638457    -6.113267     ...          2.070667
#          25%       1.657577     1.402147     ...          3.152720
#          50%       3.296596     2.888703     ...          3.442050
#          75%       4.499294     4.127967     ...          3.758045
#          max      11.688429     9.870230     ...          5.133220
# normal   count   567.000000   567.000000     ...        567.000000
#          mean     -0.793722    -1.163943     ...          3.447004
#          std       1.666871     2.086850     ...          0.419959
#          min      -5.762009    -7.259194     ...          2.053677
#          25%      -1.841628    -2.318392     ...          3.199983
#          50%      -0.951435    -1.170702     ...          3.440671
#          75%      -0.008299    -0.289249     ...          3.686890
#          max       4.658906     5.992444     ...          5.284866
#
#                  std_mfcc_3   std_mfcc_4   std_mfcc_5   std_mfcc_6  \
# type
# artifact count   711.000000   711.000000   711.000000   711.000000
#          mean      7.094745     6.063307     5.277302     5.040685
#          std       3.737527     2.810943     2.021367     1.884419
#          min       2.549151     2.711791     2.613343     2.707907
#          25%       4.313816     3.953263     3.936460     3.865823
#          50%       5.776620     5.201144     4.538451     4.483664
#          75%       8.871540     7.439557     6.056778     5.505877
#          max      22.903998    18.111111    13.324892    21.906448
# extrahls count   459.000000   459.000000   459.000000   459.000000
#          mean     10.317839     9.062743     7.724193     6.605676
#          std       2.661469     2.015059     1.482742     1.256447
#          min       5.595624     4.875312     4.334527     4.036425
#          25%       8.611444     7.557254     6.638380     5.623956
#          50%       9.611099     8.796037     7.642464     6.455074
#          75%      11.455186    10.505616     8.702968     7.386712
#          max      21.177986    15.050888    11.941338    10.424041
# murmur   count  1179.000000  1179.000000  1179.000000  1179.000000
#          mean      8.031150     7.510515     7.014494     6.604949
#          std       2.295815     1.905399     1.639205     1.430740
#          min       4.367963     4.305328     3.740081     3.858250
#          25%       6.304303     6.065162     5.793923     5.521213
#          50%       7.495755     7.096023     6.717218     6.509124
#          75%       9.321239     8.759014     8.048978     7.509168
#          max      19.895263    15.014569    12.660809    11.305898
# normal   count   567.000000   567.000000   567.000000   567.000000
#          mean     10.777198     9.207017     7.384354     6.286512
#          std       3.229457     2.681620     1.452508     1.135197
#          min       4.016505     3.742125     3.920812     3.078940
#          25%       8.790937     7.443732     6.304892     5.514282
#          50%      10.163398     8.818344     7.352532     6.218289
#          75%      12.740696    10.402580     8.325259     7.023391
#          max      23.976757    20.436292    11.398349    11.142677
#
#                  std_mfcc_7   std_mfcc_8   std_mfcc_9     std_rmse  \
# type
# artifact count   711.000000   711.000000   711.000000   711.000000
#          mean      4.788173     4.551232     4.394815     0.555737
#          std       1.487055     1.258657     1.233267     0.738617
#          min       2.630633     2.783744     2.927359     0.033955
#          25%       3.847954     3.738904     3.601170     0.103371
#          50%       4.404404     4.227496     4.068660     0.305801
#          75%       5.256271     4.975430     4.740334     0.683161
#          max      11.159648    12.089528    11.722735     4.890647
# extrahls count   459.000000   459.000000   459.000000   459.000000
#          mean      5.785206     5.169141     4.729247     1.182774
#          std       0.987974     0.778556     0.665177     0.795209
#          min       3.374481     2.879043     3.090832     0.233713
#          25%       5.044102     4.567402     4.261372     0.561147
#          50%       5.709554     5.162151     4.657694     0.916937
#          75%       6.438188     5.741625     5.247898     1.593586
#          max       8.626086     7.364409     6.562012     4.226676
# murmur   count  1179.000000  1179.000000  1179.000000  1179.000000
#          mean      6.148429     5.747471     5.404413     0.909512
#          std       1.209410     1.032829     0.876372     0.495255
#          min       3.578316     3.510655     3.441993     0.244248
#          25%       5.255245     5.019103     4.790129     0.472139
#          50%       6.069686     5.659783     5.336354     0.794519
#          75%       6.930726     6.442302     5.944124     1.225245
#          max       9.914230     9.260309     8.208065     2.627687
# normal   count   567.000000   567.000000   567.000000   567.000000
#          mean      5.444307     4.986418     4.626088     1.447138
#          std       0.835522     0.856484     0.667790     1.131149
#          min       2.891202     3.128161     2.763630     0.241857
#          25%       4.881739     4.380462     4.198405     0.624723
#          50%       5.429030     4.952385     4.624247     0.991345
#          75%       5.991156     5.473361     5.086982     1.996868
#          max       7.565690     7.648657     6.884022     5.225293
#
#                     std_zcr
# type
# artifact count   711.000000
#          mean      0.064309
#          std       0.043002
#          min       0.008618
#          25%       0.031837
#          50%       0.054825
#          75%       0.092703
#          max       0.319099
# extrahls count   459.000000
#          mean      0.101499
#          std       0.030799
#          min       0.010494
#          25%       0.086262
#          50%       0.102489
#          75%       0.120973
#          max       0.176267
# murmur   count  1179.000000
#          mean      0.107305
#          std       0.051379
#          min       0.002045
#          25%       0.095409
#          50%       0.116234
#          75%       0.140627
#          max       0.188889
# normal   count   567.000000
#          mean      0.095522
#          std       0.024182
#          min       0.008550
#          25%       0.081168
#          50%       0.094617
#          75%       0.111703
#          max       0.160658
#
# [32 rows x 128 columns]
